# %%
import pandas as pd

df = pd.read_csv("data/lr_train.csv")

# %%
df
# Out:
#             0         1         2         3         4         5         6  \
# 0    0.338817  0.202486  0.039839  0.689487  0.477370  0.438311  0.610515
# 1    0.638329  0.116307  0.892762  0.463389  0.891524  0.809020  0.525003
# 2    0.624716  0.020289  0.297174  0.615548  0.771885  0.412550  0.606426
# 3    0.431058  0.295525  0.471388  0.823603  0.377182  0.150620  0.813601
# 4    0.199354  0.017857  0.401682  0.592174  0.288354  0.509680  0.586697
# ..        ...       ...       ...       ...       ...       ...       ...
# 162  0.502982  0.198147  0.363904  0.667788  0.634882  0.347165  0.615144
# 163  0.324266  0.369618  0.204912  0.486381  0.622411  0.223834  0.472711
# 164  0.293678  0.543147  0.174287  0.489932  0.626461  0.314251  0.523673
# 165  0.601395  0.770594  0.604859  0.441934  0.507909  0.301477  0.805517
# 166  0.501149  0.272043  0.355718  0.439114  0.832593  0.111165  0.553389
#
#             7         8         9  ...     12710     12711     12712  \
# ...

# %%
import torch

tensor = torch.tensor(df.values, dtype=torch.float32)

# %%
tensor.shape
# Out:
# torch.Size([167, 12720])

# %%
from MatrixVectorizer import MatrixVectorizer

MatrixVectorizer.anti_vectorize(vector=tensor[0], matrix_size=160)
# Out:
# tensor([[0.0000, 0.3388, 0.2025,  ..., 0.6702, 0.3994, 0.1218],
#         [0.3388, 0.0000, 0.0398,  ..., 0.5899, 0.0000, 0.3450],
#         [0.2025, 0.0398, 0.0000,  ..., 0.3247, 0.1656, 0.0065],
#         ...,
#         [0.6702, 0.5899, 0.3247,  ..., 0.0000, 0.2633, 0.2553],
#         [0.3994, 0.0000, 0.1656,  ..., 0.2633, 0.0000, 0.1834],
#         [0.1218, 0.3450, 0.0065,  ..., 0.2553, 0.1834, 0.0000]])
